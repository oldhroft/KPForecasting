# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

import datetime

def categorize(x):
    if x <= 30: return 0
    elif x <= 50: return 1
    else: return 2

def preprocess_3h(df):

    x = df.copy()

    x['category'] = x['Kp*10'].apply(categorize)

    x['dttm'] = x.apply(
        lambda y: datetime.datetime(
            int(y.year), int(y.month), 
            int(y.day), int(y['hour from']), 0), axis=1)
    
    x_3h = x.sort_values(by='dttm').iloc[:: 3]
    return x_3h

ROOT_PATH = '/content/drive/MyDrive/kp_data'

import os
import glob

files = glob.glob(os.path.join(ROOT_PATH, '*'))

files = dict(map(lambda x: (x.split('/')[-1], x), files))

df = pd.read_csv(
    files['All_browse_data_без_погружения_19971021_20211231_с_пропусками.csv'], 
    encoding='cp1251', na_values='N').pipe(preprocess_3h)
print(df.shape)
df.head()
# Out:
# (70776, 65)
#     year  month  day  hour from  hour to    doySin   hourSin    doyCos  \
# 0   1997     10   21          0        1 -0.505271  0.991445 -0.862961
# 3   1997     10   21          3        4 -0.507126  0.608761 -0.861872
# 6   1997     10   21          6        7 -0.508980 -0.130526 -0.860779
# 9   1997     10   21          9       10 -0.510831 -0.793353 -0.859681
# 12  1997     10   21         12       13 -0.512679 -0.991445 -0.858580
#
#      hourCos  Dst  ...  lg(E>2 MeV)  E>2 MeV G16  lg(E>2 MeV) G16  \
# 0  -0.130526  -14  ...     0.715307          NaN              NaN
# 3  -0.793353  -13  ...     0.318573          NaN              NaN
# 6  -0.991445  -15  ...     0.070838          NaN              NaN
# 9  -0.608761  -13  ...     0.501584          NaN              NaN
# 12  0.130526  -10  ...     1.011042          NaN              NaN
#
#     CH_rca (193)  CH_rca (211)  SW_spd_frcst (193)  SW_spd_frcst (211)  \
# 0            NaN           NaN                 NaN                 NaN
# 3            NaN           NaN                 NaN                 NaN
# 6            NaN           NaN                 NaN                 NaN
# 9            NaN           NaN                 NaN                 NaN
# 12           NaN           NaN                 NaN                 NaN
#
#     Unnamed: 62  category                dttm
# 0           NaN         0 1997-10-21 00:00:00
# 3           NaN         0 1997-10-21 03:00:00
# 6           NaN         0 1997-10-21 06:00:00
# 9           NaN         0 1997-10-21 09:00:00
# 12          NaN         0 1997-10-21 12:00:00
#
# [5 rows x 65 columns]

# %%
all_variables = [
    'Kp*10', 'Dst', 'B_x', 'B_gsm_y', 'B_gsm_z', 
    'B_magn', 'SW_spd', 'H_den_SWP', 'dttm', 'category'
 ]

predictors  = [
    'Kp*10', 'Dst', 'B_x', 'B_gsm_y', 'B_gsm_z', 
    'B_magn', 'SW_spd', 'H_den_SWP',
 ]

def simple_preprocessing(df):
    x = df.copy()

    x = x.bfill()

    return x

def _choose_suffix_name(forward: bool, suffix_name: str) -> str:
    if suffix_name is not None:
        return suffix_name
    else:
        return 'lead' if forward else 'lag'

def _trim(df: pd.DataFrame, forward: bool, trim: bool, lags: int) -> pd.DataFrame:
    if trim and forward:
        return df.iloc[: -lags]
    elif trim:
        return df.iloc[lags: ]
    else:
        return df

def add_lags(df: pd.DataFrame, subset: list=None, forward: bool=False,
             lags: int=1, trim: bool=False, suffix_name: str=None,
             return_cols=False) -> pd.DataFrame:

    suffix_name = _choose_suffix_name(forward, suffix_name)

    x = df.copy()

    digits = len(str(lags))

    columns = []

    if not isinstance(lags, int):
        raise ValueError(f'Lags should be int, {type(lags)} type prodided')
    elif lags < 0:
        raise ValueError(f'Lags should be non-negative')
    elif lags == 0:
        return x
    elif subset is None:
        for i in range(1, lags + 1):
            lag = - i if forward else i
            index = str(i).zfill(digits)
            column_suffix = f'_{suffix_name}_{index}'

            x = x.join(x.shift(lag).add_suffix(column_suffix))
        
        columns = x.columns.tolist()

    elif isinstance(subset, list):
        for i in range(1, lags + 1):
            lag = - i if forward else i
            index = str(i).zfill(digits)
            column_suffix = f'_{suffix_name}_{index}'
            tmp = x.loc[:, subset].shift(lag).add_suffix(column_suffix)
            columns.extend(tmp.columns)
            x = x.join(tmp)

    elif isinstance(subset, str):
        for i in range(1, lags + 1):
            lag = - i if forward else i
            index = str(i).zfill(digits)
            column_name = f'{subset}_{suffix_name}_{index}'
            columns.append(column_name)

            x = x.join(x.loc[:, subset].shift(lag).rename(column_name))
    else:
        raise ValueError(f'Subset should be str or list, providided type {type(subset)}')

    if return_cols:
        return _trim(x, forward, trim, lags), columns
    else:
        return _trim(x, forward, trim, lags)


def get_train_test(df: pd.DataFrame, columns: list, 
                   forward_steps: int, backward_steps: int, 
                   last: str='24m', last_val=None) -> tuple:

    ts_df_back, lag_cols = add_lags(df, lags=backward_steps, forward=False, 
                                    trim=True, subset=columns, 
                                    return_cols=True)
    lag_cols.extend(columns)
    ts_df_back_test = ts_df_back.set_index('dttm').last(last)

    index_test = ts_df_back_test.index
    ts_df_back_train = ts_df_back.set_index('dttm').drop(index_test)


    if last_val is not None:
        ts_df_back_val = ts_df_back_train.last(last_val)
        index_val = ts_df_back_val.index
        ts_df_back_train = ts_df_back.set_index('dttm').drop(index_val)
        df_val, lead_cols = add_lags(ts_df_back_val, lags=forward_steps,
                                       forward=True, trim=True, 
                                       subset='category', return_cols=True)

    df_train, lead_cols = add_lags(ts_df_back_train, lags=forward_steps,
                                   forward=True, trim=True, 
                                   subset='category', return_cols=True)
    df_test, lead_cols = add_lags(ts_df_back_test, lags=forward_steps, 
                                  forward=True, trim=True, 
                                  subset='category', return_cols=True)
    if last_val is not None:
        return (
            df_train.reset_index(), lag_cols,
            df_val.reset_index(), lag_cols,
            df_test.reset_index(), lead_cols)
    else:
        return (
            df_train.reset_index(), lag_cols,
            df_test.reset_index(), lead_cols)


from sklearn.metrics import multilabel_confusion_matrix, confusion_matrix
from sklearn.metrics import f1_score

from types import FunctionType

def columnwise_score(scoring_func: FunctionType, 
                     preds_df: pd.DataFrame, 
                     true_df: pd.DataFrame,
                     **kwargs) -> pd.Series:

    score = pd.Series(dtype='float64')
    for (column_pred, y_pred), (columns_true, y_true) in zip(preds_df.iteritems(), 
                                                             true_df.iteritems()):
        score[column_pred] = scoring_func(y_pred, y_true, **kwargs)
    
    return score

# %%
df_train, lag_cols, df_val, _, df_test, lead_cols = get_train_test(
    df.pipe(simple_preprocessing), predictors, 
    24 // 3, 24, last_val='24m')

# %%
X_train, y_train = df_train[lag_cols], df_train[lead_cols[0]]
X_val, y_val = df_val[lag_cols], df_val[lead_cols[0]]
X_test, y_test = df_test[lag_cols], df_test[lead_cols]

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.linear_model import RidgeClassifier
from sklearn.base import clone

import time

def validate(model, params: list, param_name: str, scoring: FunctionType,
             X_train: pd.DataFrame, y_train: pd.Series,
             X_val: pd.DataFrame, y_val: pd.Series,
             verbose: bool=True, **kwargs) -> list:
    
    scores = []

    for param in params:

        start_time = time.time()
        model_param = clone(model).set_params(**{param_name: param})
        if verbose: print(model_param.get_params())
        if verbose: print('Fitting param {} = {}'.format(param_name, param))
        model_param.fit(X_train, y_train)

        y_preds = model_param.predict(X_val)
        scores.append(scoring(y_preds, y_val, **kwargs))
        end_time = time.time()
        if verbose: print('Param {} = {}, time {:.2f}'.format(param_name, 
                                                              param, 
                                                              end_time - start_time))

    return scores

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

model = make_pipeline(
    StandardScaler(),
    RidgeClassifier(random_state=17))

params = [.1, 1, 10, 20, 40, 80, 100, 1000]


scores = validate(model, params, 'ridgeclassifier__alpha', f1_score,
                  X_train, y_train,
                  X_val, y_val, average='macro')
# Out:
# {'memory': None, 'steps': [('standardscaler', StandardScaler()), ('ridgeclassifier', RidgeClassifier(alpha=0.1, random_state=17))], 'verbose': False, 'standardscaler': StandardScaler(), 'ridgeclassifier': RidgeClassifier(alpha=0.1, random_state=17), 'standardscaler__copy': True, 'standardscaler__with_mean': True, 'standardscaler__with_std': True, 'ridgeclassifier__alpha': 0.1, 'ridgeclassifier__class_weight': None, 'ridgeclassifier__copy_X': True, 'ridgeclassifier__fit_intercept': True, 'ridgeclassifier__max_iter': None, 'ridgeclassifier__normalize': 'deprecated', 'ridgeclassifier__positive': False, 'ridgeclassifier__random_state': 17, 'ridgeclassifier__solver': 'auto', 'ridgeclassifier__tol': 0.001}
# Fitting param ridgeclassifier__alpha = 0.1
# Param ridgeclassifier__alpha = 0.1, time 0.72
# {'memory': None, 'steps': [('standardscaler', StandardScaler()), ('ridgeclassifier', RidgeClassifier(alpha=1, random_state=17))], 'verbose': False, 'standardscaler': StandardScaler(), 'ridgeclassifier': RidgeClassifier(alpha=1, random_state=17), 'standardscaler__copy': True, 'standardscaler__with_mean': True, 'standardscaler__with_std': True, 'ridgeclassifier__alpha': 1, 'ridgeclassifier__class_weight': None, 'ridgeclassifier__copy_X': True, 'ridgeclassifier__fit_intercept': True, 'ridgeclassifier__max_iter': None, 'ridgeclassifier__normalize': 'deprecated', 'ridgeclassifier__positive': False, 'ridgeclassifier__random_state': 17, 'ridgeclassifier__solver': 'auto', 'ridgeclassifier__tol': 0.001}
# Fitting param ridgeclassifier__alpha = 1
# Param ridgeclassifier__alpha = 1, time 0.65
# {'memory': None, 'steps': [('standardscaler', StandardScaler()), ('ridgeclassifier', RidgeClassifier(alpha=10, random_state=17))], 'verbose': False, 'standardscaler': StandardScaler(), 'ridgeclassifier': RidgeClassifier(alpha=10, random_state=17), 'standardscaler__copy': True, 'standardscaler__with_mean': True, 'standardscaler__with_std': True, 'ridgeclassifier__alpha': 10, 'ridgeclassifier__class_weight': None, 'ridgeclassifier__copy_X': True, 'ridgeclassifier__fit_intercept': True, 'ridgeclassifier__max_iter': None, 'ridgeclassifier__normalize': 'deprecated', 'ridgeclassifier__positive': False, 'ridgeclassifier__random_state': 17, 'ridgeclassifier__solver': 'auto', 'ridgeclassifier__tol': 0.001}
# Fitting param ridgeclassifier__alpha = 10
# Param ridgeclassifier__alpha = 10, time 0.63
# {'memory': None, 'steps': [('standardscaler', StandardScaler()), ('ridgeclassifier', RidgeClassifier(alpha=20, random_state=17))], 'verbose': False, 'standardscaler': StandardScaler(), 'ridgeclassifier': RidgeClassifier(alpha=20, random_state=17), 'standardscaler__copy': True, 'standardscaler__with_mean': True, 'standardscaler__with_std': True, 'ridgeclassifier__alpha': 20, 'ridgeclassifier__class_weight': None, 'ridgeclassifier__copy_X': True, 'ridgeclassifier__fit_intercept': True, 'ridgeclassifier__max_iter': None, 'ridgeclassifier__normalize': 'deprecated', 'ridgeclassifier__positive': False, 'ridgeclassifier__random_state': 17, 'ridgeclassifier__solver': 'auto', 'ridgeclassifier__tol': 0.001}
# Fitting param ridgeclassifier__alpha = 20
# Param ridgeclassifier__alpha = 20, time 0.65
# {'memory': None, 'steps': [('standardscaler', StandardScaler()), ('ridgeclassifier', RidgeClassifier(alpha=40, random_state=17))], 'verbose': False, 'standardscaler': StandardScaler(), 'ridgeclassifier': RidgeClassifier(alpha=40, random_state=17), 'standardscaler__copy': True, 'standardscaler__with_mean': True, 'standardscaler__with_std': True, 'ridgeclassifier__alpha': 40, 'ridgeclassifier__class_weight': None, 'ridgeclassifier__copy_X': True, 'ridgeclassifier__fit_intercept': True, 'ridgeclassifier__max_iter': None, 'ridgeclassifier__normalize': 'deprecated', 'ridgeclassifier__positive': False, 'ridgeclassifier__random_state': 17, 'ridgeclassifier__solver': 'auto', 'ridgeclassifier__tol': 0.001}
# Fitting param ridgeclassifier__alpha = 40
# Param ridgeclassifier__alpha = 40, time 0.64
# {'memory': None, 'steps': [('standardscaler', StandardScaler()), ('ridgeclassifier', RidgeClassifier(alpha=80, random_state=17))], 'verbose': False, 'standardscaler': StandardScaler(), 'ridgeclassifier': RidgeClassifier(alpha=80, random_state=17), 'standardscaler__copy': True, 'standardscaler__with_mean': True, 'standardscaler__with_std': True, 'ridgeclassifier__alpha': 80, 'ridgeclassifier__class_weight': None, 'ridgeclassifier__copy_X': True, 'ridgeclassifier__fit_intercept': True, 'ridgeclassifier__max_iter': None, 'ridgeclassifier__normalize': 'deprecated', 'ridgeclassifier__positive': False, 'ridgeclassifier__random_state': 17, 'ridgeclassifier__solver': 'auto', 'ridgeclassifier__tol': 0.001}
# Fitting param ridgeclassifier__alpha = 80
# Param ridgeclassifier__alpha = 80, time 0.62
# {'memory': None, 'steps': [('standardscaler', StandardScaler()), ('ridgeclassifier', RidgeClassifier(alpha=100, random_state=17))], 'verbose': False, 'standardscaler': StandardScaler(), 'ridgeclassifier': RidgeClassifier(alpha=100, random_state=17), 'standardscaler__copy': True, 'standardscaler__with_mean': True, 'standardscaler__with_std': True, 'ridgeclassifier__alpha': 100, 'ridgeclassifier__class_weight': None, 'ridgeclassifier__copy_X': True, 'ridgeclassifier__fit_intercept': True, 'ridgeclassifier__max_iter': None, 'ridgeclassifier__normalize': 'deprecated', 'ridgeclassifier__positive': False, 'ridgeclassifier__random_state': 17, 'ridgeclassifier__solver': 'auto', 'ridgeclassifier__tol': 0.001}
# Fitting param ridgeclassifier__alpha = 100
# Param ridgeclassifier__alpha = 100, time 0.62
# {'memory': None, 'steps': [('standardscaler', StandardScaler()), ('ridgeclassifier', RidgeClassifier(alpha=1000, random_state=17))], 'verbose': False, 'standardscaler': StandardScaler(), 'ridgeclassifier': RidgeClassifier(alpha=1000, random_state=17), 'standardscaler__copy': True, 'standardscaler__with_mean': True, 'standardscaler__with_std': True, 'ridgeclassifier__alpha': 1000, 'ridgeclassifier__class_weight': None, 'ridgeclassifier__copy_X': True, 'ridgeclassifier__fit_intercept': True, 'ridgeclassifier__max_iter': None, 'ridgeclassifier__normalize': 'deprecated', 'ridgeclassifier__positive': False, 'ridgeclassifier__random_state': 17, 'ridgeclassifier__solver': 'auto', 'ridgeclassifier__tol': 0.001}
# Fitting param ridgeclassifier__alpha = 1000
# Param ridgeclassifier__alpha = 1000, time 0.65

# %%
scores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fa8cef49474b> in <module>()
# ----> 1 scores
#
# NameError: name 'scores' is not defined

# %%
from sklearn.multioutput import MultiOutputClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

model = make_pipeline(
    StandardScaler(),
    MultiOutputClassifier(RidgeClassifier(random_state=17, alpha=100)))

df_train, lag_cols, df_test, lead_cols = get_train_test(
    df.pipe(simple_preprocessing), predictors, 24 // 3, 24)

X_train, y_train = df_train[lag_cols], df_train[lead_cols]
X_test, y_test = df_test[lag_cols], df_test[lead_cols]

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('multioutputclassifier',
#                  MultiOutputClassifier(estimator=RidgeClassifier(alpha=100,
#                                                                  random_state=17)))])

# %%
preds = model.predict(X_test)
preds = pd.DataFrame(preds, columns=lead_cols)
f1_weighted_res = columnwise_score(f1_score, preds, y_test, average='macro')

# %%
f1_weighted_res.to_csv(os.path.join(ROOT_PATH, 'ridge_train_val.csv'))

# %%
f1_weighted_res
# Out:
# category_lead_1    0.396085
# category_lead_2    0.350668
# category_lead_3    0.338497
# category_lead_4    0.330301
# category_lead_5    0.327134
# category_lead_6    0.327168
# category_lead_7    0.322322
# category_lead_8    0.320626
# dtype: float64

# %%
from sklearn.metrics import confusion_matrix

def columnwise_confusion_matrix(preds_df: pd.DataFrame, y_true_df: pd.DataFrame, 
                                categories: list) -> list:

    all_matrices = {}
    for col in preds_df.columns:

        matrix = pd.DataFrame(confusion_matrix(y_true_df[col], preds_df[col]),
                              index=categories, columns=categories)
        all_matrices[col] = matrix

    return all_matrices

# %%
confusion_matrices = columnwise_confusion_matrix(preds, y_test, [0, 1, 2])

# %%
matr_path = os.path.join(ROOT_PATH, 'metrics')

import os
if not os.path.exists(matr_path): os.mkdir(matr_path)

for key, matrix in confusion_matrices.items():

    matrix.to_excel(
        os.path.join(matr_path, f'ridge_test_val_confusion_matrix_{key}.xlsx'))

# %%
import seaborn as sns

def plot_all_confusion_matrices(matrices: list, 
                                h: int=2, w: int= 2, **kwargs) -> None:

    n = len(matrices)

    f, ax = plt.subplots(n, 1, sharex=True)

    for i, (key, matrix) in enumerate(matrices.items()):
        sns.heatmap(matrix.astype('int'), ax=ax[i], **kwargs)
        ax[i].set_title(key)

    f.set_figheight(n * h)
    f.set_figwidth(w)

    plt.tight_layout()

# %%
plot_all_confusion_matrices(confusion_matrices, h=3, w=6, annot=True, fmt='.5g', cmap='hot')

# %%
files = glob.glob(os.path.join(ROOT_PATH, '*'))

# %%
files_res = [
 '/content/drive/MyDrive/kp_data/xgb_cv.csv',
 '/content/drive/MyDrive/kp_data/ridge_cv.csv',
 '/content/drive/MyDrive/kp_data/rf_cv.csv',
 '/content/drive/MyDrive/kp_data/xgb_test_val.csv',
 '/content/drive/MyDrive/kp_data/rf_test_val.csv',
 '/content/drive/MyDrive/kp_data/ensemble_xgb_rf.csv',
 '/content/drive/MyDrive/kp_data/ridge_train_val.csv'
]

# %%
files_res = list(map(lambda x: (x.split('/')[-1].split('.')[0], x), files_res))

# %%
all_res = pd.DataFrame({
    fname: pd.read_csv(path, squeeze=True, index_col=0)
    for fname, path in files_res
})

# %%
all_res.to_excel(os.path.join(ROOT_PATH, 'cv_result.xlsx'))
